# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"


import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train = pd.read_csv(r'\\Neptune\RiskMgmtArchive\3 Temp Hold\Temp_Jason\research\train.csv')
# Out:
# C:\Users\yam\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.loc[train['Season'] == 2017, 'Orientation'] = train.loc[train['Season'] == 2017, 'Orientation'] + 90

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: str(x).lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
  


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: str(x).lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats,rush_feats,static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# C:\Users\yam\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Wall time: 1min 43s

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-1.25301814, -0.41354731, -0.18639474, ...,  2.19167184,
#         -1.6676964 , -0.07074881],
#        [-0.91178801, -0.41354731, -0.18639474, ..., -0.77134982,
#          0.44022727, -0.07074881],
#        [-1.34898912, -0.41354731, -0.18639474, ..., -0.77134982,
#          0.44022727,  0.01629631],
#        ...,
#        [-0.91178801, -0.41354731, -0.18639474, ...,  2.19167184,
#         -1.93118686,  0.01629631],
#        [-1.18903749, -0.41354731, -0.18639474, ..., -0.77134982,
#          0.44022727,  0.01629631],
#        [ 1.35952508, -0.41354731, -0.18639474, ...,  0.71016101,
#         -0.08675365,  0.19038655]])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 3s 182us/step - loss: 5.5874
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08248, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 5.0812
#
# Epoch 00002: CRPS_score_val improved from 0.08248 to 0.07827, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 4.6677
#
# Epoch 00003: CRPS_score_val improved from 0.07827 to 0.06469, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 4.2588
#
# Epoch 00004: CRPS_score_val improved from 0.06469 to 0.04376, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 3.8729
#
# Epoch 00005: CRPS_score_val improved from 0.04376 to 0.02581, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 3.5450
#
# Epoch 00006: CRPS_score_val improved from 0.02581 to 0.01790, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 3.3141
#
# Epoch 00007: CRPS_score_val improved from 0.01790 to 0.01533, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 3.1656
#
# Epoch 00008: CRPS_score_val improved from 0.01533 to 0.01434, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 3.0719
#
# Epoch 00009: CRPS_score_val improved from 0.01434 to 0.01380, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 3.0213
#
# Epoch 00010: CRPS_score_val improved from 0.01380 to 0.01365, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.9792
#
# Epoch 00011: CRPS_score_val improved from 0.01365 to 0.01358, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.9436
#
# Epoch 00012: CRPS_score_val improved from 0.01358 to 0.01348, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.9048
#
# Epoch 00013: CRPS_score_val improved from 0.01348 to 0.01338, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8863
#
# Epoch 00014: CRPS_score_val improved from 0.01338 to 0.01334, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8671
#
# Epoch 00015: CRPS_score_val improved from 0.01334 to 0.01329, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8556
#
# Epoch 00016: CRPS_score_val improved from 0.01329 to 0.01324, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8404
#
# Epoch 00017: CRPS_score_val improved from 0.01324 to 0.01321, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8222
#
# Epoch 00018: CRPS_score_val improved from 0.01321 to 0.01316, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.8074
#
# Epoch 00019: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7961
#
# Epoch 00020: CRPS_score_val improved from 0.01312 to 0.01309, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7911
#
# Epoch 00021: CRPS_score_val improved from 0.01309 to 0.01308, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.7802
#
# Epoch 00022: CRPS_score_val improved from 0.01308 to 0.01304, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7735
#
# Epoch 00023: CRPS_score_val improved from 0.01304 to 0.01303, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7635
#
# Epoch 00024: CRPS_score_val improved from 0.01303 to 0.01301, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7605
#
# Epoch 00025: CRPS_score_val improved from 0.01301 to 0.01300, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7519
#
# Epoch 00026: CRPS_score_val improved from 0.01300 to 0.01299, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7456
#
# Epoch 00027: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.7412
#
# Epoch 00028: CRPS_score_val did not improve from 0.01296
# Epoch 29/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.7382
#
# Epoch 00029: CRPS_score_val did not improve from 0.01296
# Epoch 30/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7314
#
# Epoch 00030: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.7251
#
# Epoch 00031: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 32/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.7214
#
# Epoch 00032: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.7157
#
# Epoch 00033: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.7134
#
# Epoch 00034: CRPS_score_val improved from 0.01292 to 0.01292, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7067
#
# Epoch 00035: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 36/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7063
#
# Epoch 00036: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7000
#
# Epoch 00037: CRPS_score_val did not improve from 0.01290
# Epoch 38/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6973
#
# Epoch 00038: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 39/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6924
#
# Epoch 00039: CRPS_score_val improved from 0.01288 to 0.01288, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6918
#
# Epoch 00040: CRPS_score_val did not improve from 0.01288
# Epoch 41/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6801
#
# Epoch 00041: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 42/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6772
#
# Epoch 00042: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6809
#
# Epoch 00043: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 44/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6731
#
# Epoch 00044: CRPS_score_val did not improve from 0.01286
# Epoch 45/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6722
#
# Epoch 00045: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 46/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6685
#
# Epoch 00046: CRPS_score_val did not improve from 0.01285
# Epoch 47/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6631
#
# Epoch 00047: CRPS_score_val did not improve from 0.01285
# Epoch 48/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6670
#
# Epoch 00048: CRPS_score_val did not improve from 0.01285
# Epoch 49/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6658
#
# Epoch 00049: CRPS_score_val did not improve from 0.01285
# Epoch 50/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6622
#
# Epoch 00050: CRPS_score_val did not improve from 0.01285
# Epoch 51/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6605
#
# Epoch 00051: CRPS_score_val did not improve from 0.01285
# Epoch 52/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6520
#
# Epoch 00052: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 53/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6556
#
# Epoch 00053: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 54/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6523
#
# Epoch 00054: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 55/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6492
#
# Epoch 00055: CRPS_score_val did not improve from 0.01284
# Epoch 56/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6519
#
# Epoch 00056: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 57/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6421
#
# Epoch 00057: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 58/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6430
#
# Epoch 00058: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 59/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6423
#
# Epoch 00059: CRPS_score_val did not improve from 0.01282
# Epoch 60/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6415
#
# Epoch 00060: CRPS_score_val did not improve from 0.01282
# Epoch 61/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6348
#
# Epoch 00061: CRPS_score_val did not improve from 0.01282
# Epoch 62/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.6371
#
# Epoch 00062: CRPS_score_val did not improve from 0.01282
# Epoch 63/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6283
#
# Epoch 00063: CRPS_score_val did not improve from 0.01282
# Epoch 64/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6313
#
# Epoch 00064: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 65/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6288
#
# Epoch 00065: CRPS_score_val did not improve from 0.01281
# Epoch 66/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.6278
#
# Epoch 00066: CRPS_score_val did not improve from 0.01281
# Epoch 67/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6241
#
# Epoch 00067: CRPS_score_val did not improve from 0.01281
# Epoch 68/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6266
#
# Epoch 00068: CRPS_score_val did not improve from 0.01281
# Epoch 69/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6244
#
# Epoch 00069: CRPS_score_val did not improve from 0.01281
# Epoch 70/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6220
#
# Epoch 00070: CRPS_score_val did not improve from 0.01281
# Epoch 71/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6192
#
# Epoch 00071: CRPS_score_val did not improve from 0.01281
# Epoch 72/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6161
#
# Epoch 00072: CRPS_score_val did not improve from 0.01281
# Epoch 73/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6153
#
# Epoch 00073: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 74/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6153
#
# Epoch 00074: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 75/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6105
#
# Epoch 00075: CRPS_score_val did not improve from 0.01280
# Epoch 76/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6056
#
# Epoch 00076: CRPS_score_val did not improve from 0.01280
# Epoch 77/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6037
#
# Epoch 00077: CRPS_score_val did not improve from 0.01280
# Epoch 78/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5999
#
# Epoch 00078: CRPS_score_val did not improve from 0.01280
# Epoch 79/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6036
#
# Epoch 00079: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 80/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5993
#
# Epoch 00080: CRPS_score_val did not improve from 0.01280
# Epoch 81/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.6012
#
# Epoch 00081: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 82/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5935
#
# Epoch 00082: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 83/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5939
#
# Epoch 00083: CRPS_score_val did not improve from 0.01279
# Epoch 84/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5901
#
# Epoch 00084: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 85/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5887
#
# Epoch 00085: CRPS_score_val did not improve from 0.01279
# Epoch 86/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5823
#
# Epoch 00086: CRPS_score_val did not improve from 0.01279
# Epoch 87/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.5849
#
# Epoch 00087: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 88/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5812
#
# Epoch 00088: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 89/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.5803
#
# Epoch 00089: CRPS_score_val did not improve from 0.01278
# Epoch 90/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5744
#
# Epoch 00090: CRPS_score_val did not improve from 0.01278
# Epoch 91/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5758
#
# Epoch 00091: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 92/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5732
#
# Epoch 00092: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 93/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5707
#
# Epoch 00093: CRPS_score_val did not improve from 0.01276
# Epoch 94/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5653
#
# Epoch 00094: CRPS_score_val did not improve from 0.01276
# Epoch 95/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5638
#
# Epoch 00095: CRPS_score_val did not improve from 0.01276
# Epoch 96/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5638
#
# Epoch 00096: CRPS_score_val did not improve from 0.01276
# Epoch 97/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5625
#
# Epoch 00097: CRPS_score_val did not improve from 0.01276
# Epoch 98/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.5574
#
# Epoch 00098: CRPS_score_val did not improve from 0.01276
# Epoch 99/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.5575
#
# Epoch 00099: CRPS_score_val did not improve from 0.01276
# Epoch 100/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5514
#
# Epoch 00100: CRPS_score_val did not improve from 0.01276
# the 1 fold crps is 0.012762
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 4s 200us/step - loss: 5.5874
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08225, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 5.0858
#
# Epoch 00002: CRPS_score_val improved from 0.08225 to 0.07754, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 4.6669
#
# Epoch 00003: CRPS_score_val improved from 0.07754 to 0.06403, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 4.2599
#
# Epoch 00004: CRPS_score_val improved from 0.06403 to 0.04095, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.8448
#
# Epoch 00005: CRPS_score_val improved from 0.04095 to 0.02429, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.5324
#
# Epoch 00006: CRPS_score_val improved from 0.02429 to 0.01769, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 3.3183
#
# Epoch 00007: CRPS_score_val improved from 0.01769 to 0.01506, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.1783
#
# Epoch 00008: CRPS_score_val improved from 0.01506 to 0.01412, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.0885
#
# Epoch 00009: CRPS_score_val improved from 0.01412 to 0.01375, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 3.0306
#
# Epoch 00010: CRPS_score_val improved from 0.01375 to 0.01352, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.9865
#
# Epoch 00011: CRPS_score_val improved from 0.01352 to 0.01340, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.9554
#
# Epoch 00012: CRPS_score_val improved from 0.01340 to 0.01331, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.9296
#
# Epoch 00013: CRPS_score_val improved from 0.01331 to 0.01326, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8929
#
# Epoch 00014: CRPS_score_val improved from 0.01326 to 0.01323, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.8768
#
# Epoch 00015: CRPS_score_val improved from 0.01323 to 0.01320, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8608
#
# Epoch 00016: CRPS_score_val improved from 0.01320 to 0.01313, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.8405
#
# Epoch 00017: CRPS_score_val improved from 0.01313 to 0.01310, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.8312
#
# Epoch 00018: CRPS_score_val improved from 0.01310 to 0.01306, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8209
#
# Epoch 00019: CRPS_score_val improved from 0.01306 to 0.01302, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8092
#
# Epoch 00020: CRPS_score_val improved from 0.01302 to 0.01301, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8043
#
# Epoch 00021: CRPS_score_val did not improve from 0.01301
# Epoch 22/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.7976
#
# Epoch 00022: CRPS_score_val improved from 0.01301 to 0.01298, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7855
#
# Epoch 00023: CRPS_score_val did not improve from 0.01298
# Epoch 24/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.7769
#
# Epoch 00024: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7760
#
# Epoch 00025: CRPS_score_val improved from 0.01296 to 0.01292, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.7635
#
# Epoch 00026: CRPS_score_val did not improve from 0.01292
# Epoch 27/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.7544
#
# Epoch 00027: CRPS_score_val did not improve from 0.01292
# Epoch 28/100
# 16384/18537 [=========================>....] - ETA: 0s - loss: 2.7489
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-9b1f097e8a72> in <module>()
#      16         tr_x,tr_y = X[tr_inds],y[tr_inds]
#      17         val_x,val_y = X[val_inds],y[val_inds]
# ---> 18         model,crps = get_model(tr_x,tr_y,val_x,val_y)
#      19         models.append(model)
#      20         print("the %d fold crps is %f"%((k_fold+1),crps))
#
# <ipython-input-118-dfa7820fa62f> in get_model(x_tr, y_tr, x_val, y_val)
#      33
#      34
# ---> 35     model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
#      36     model.load_weights("best_model.h5")
#      37
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
train_x = train_basetable.copy()
train_y99 =(train_x.Yards + 99).reset_index(drop=True)
train_x.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)
train_x = train_x.values

# %%
train_x
# Out:
# array([[ 3.75,  1.  ,  0.  , ...,  3.  ,  2.  ,  6.  ],
#        [ 4.07,  0.  ,  0.  , ...,  1.  , 10.  ,  6.  ],
#        [ 3.66,  1.  ,  0.  , ...,  1.  , 10.  ,  7.  ],
#        ...,
#        [ 4.07,  0.  ,  0.  , ...,  3.  ,  1.  ,  7.  ],
#        [ 3.81,  0.  ,  0.  , ...,  1.  , 10.  ,  7.  ],
#        [ 6.2 ,  0.  ,  0.  , ...,  2.  ,  8.  ,  9.  ]])

# %%
#loss function
def crps_eval(y_pred, dataset, is_higher_better=False):
    labels = dataset.get_label()
    labels = labels.astype('int')
    y_true = np.zeros((len(labels),199))
    for i, v in enumerate(labels):
        y_true[i, v:] = 1
    y_pred = y_pred.reshape(-1, 199, order='F')
    y_pred = np.clip(y_pred.cumsum(axis=1), 0, 1)
    return 'crps', np.mean((y_pred - y_true)**2), False

# %%
# hyper parameters
params = {'max_depth':6, 'lambda_l1': 0.5, 'lambda_l2': 0.5,
 'num_leaves': 45, 'feature_fraction': 0.4,
 'subsample': 0.4, 'min_child_samples': 15,
 'learning_rate': 0.02,
 'num_iterations': 10000, 'random_state': 42,
 'objective': 'multiclass',
 'min_gain_to_split':0.9,
 'num_class':199,
 'metric':'None'}

# %%
import lightgbm as lgb
for k in range(1):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(train_x)):
        tr_x, tr_y = train_x[tr_inds], train_y99[tr_inds]    
        vl_x, v_y = train_x[val_inds], train_y99[val_inds] 
        dtrain = lgb.Dataset(tr_x, label= tr_y)
        dvalid = lgb.Dataset(vl_x, label= v_y)
        model = lgb.train(params, dtrain,
                              num_boost_round=100000,
                              valid_sets=[dtrain,dvalid],
                              early_stopping_rounds=10,
                              verbose_eval=100,
                              feval=crps_eval)
# Out:
# C:\Users\yam\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 10 rounds.
# [100]	training's crps: 0.0125095	valid_1's crps: 0.0133149
# [200]	training's crps: 0.0116006	valid_1's crps: 0.0130605
# [300]	training's crps: 0.0112342	valid_1's crps: 0.0129708
# [400]	training's crps: 0.0110733	valid_1's crps: 0.0129364
# [500]	training's crps: 0.0110171	valid_1's crps: 0.012922
# [600]	training's crps: 0.0110091	valid_1's crps: 0.0129189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-01c6e8be79d6> in <module>()
#      12                               early_stopping_rounds=10,
#      13                               verbose_eval=100,
# ---> 14                               feval=crps_eval)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:
